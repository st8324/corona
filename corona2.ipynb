# %%
# %matplotlib inline
import pandas as pd                # 데이터를 저장하고 처리하는 패키지
import matplotlib as mpl           # 그래프를 그리는 패키지
import matplotlib.pyplot as plt    # 그래프를 그리는 패키지
# csv 파일을 읽어서 DataFrame 객체로 만듦. 인덱스 컬럼은 point로 설정
df = pd.read_csv('corona2.csv', index_col='day',encoding='utf-8')
df    # df 표시
# Out:
#         day_confirmed  day_death  day_release
# day
# 1월 20일              1          0            0
# 1월 24일              0          0            0
# 1월 26일              1          0            0
# 1월 27일              1          0            0
# 1월 30일              1          0            0
# ...               ...        ...          ...
# 4월 22일             11          1           64
# 4월 23일              8          2          134
# 4월 24일              6          0           90
# 4월 25일             10          0          134
# 4월 26일             10          2           82
#
# [88 rows x 3 columns]

# %%
font_name = mpl.font_manager.FontProperties(fname='C:/Windows/Fonts/malgun.ttf').get_name()
mpl.rc('font', family=font_name)

# %%
ax = df.plot( title='확진자수', figsize=(12, 4), legend=True, fontsize=12)
ax.legend(['일일확진', '일일사망', '일일해제'], fontsize=12)    # 범례 지정
